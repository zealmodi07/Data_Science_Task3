# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from CSV file

# %%
sample_s=pd.read_csv("/content/SampleSuperstore.csv")
print(sample_s.head())
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
sample_s.sample(10)
# Out:
#            Ship Mode      Segment        Country             City       State  \
# 3826  Standard Class    Corporate  United States           Dallas       Texas
# 8598  Standard Class    Corporate  United States           Fresno  California
# 1600    Second Class     Consumer  United States       Carrollton       Texas
# 9204  Standard Class    Corporate  United States      Los Angeles  California
# 8369  Standard Class     Consumer  United States      Los Angeles  California
# 7801    Second Class     Consumer  United States           Fresno  California
# 8586  Standard Class    Corporate  United States      Los Angeles  California
# 7816    Second Class  Home Office  United States  North Las Vegas      Nevada
# 9461  Standard Class  Home Office  United States         Lakewood  California
# 9529        Same Day    Corporate  United States         Beaumont       Texas
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# ...

# %% [markdown]
# # Check the missing Value

# %%
sample_s.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
print(sample_s.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB
# None

# %%
sample_s.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
sample_s.shape
# Out:
# (9994, 13)

# %%
sample_s.duplicated().sum()
# Out:
# 17

# %%
sample_s.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sample_s.corr()
# Out:
# <ipython-input-31-4f5408ca254b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sample_s.corr()
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sample_s.cov()
# Out:
# <ipython-input-32-e8c80a53853c>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sample_s.cov()
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %%
sample_s.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288      2
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370      2
# Standard Class  Consumer     United States  San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780      2
#                                             Los Angeles    California  90036        West     Office Supplies  Paper         19.440   3         0.0        9.3312      2
# ...

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=sample_s)
# Out:
# <BarContainer object of 9994 artists>

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='State',data=sample_s,palette='colorblind')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Sub-Category',data=sample_s,palette='colorblind')
plt.xticks(rotation=90)
plt.show()

# %%
fig,axes = plt.subplots(1,1,figsize=(10,6))
sns.heatmap(sample_s.corr(),annot=True)
# Out:
# <ipython-input-63-1f198d0d4d86>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sample_s.corr(),annot=True)
# <Axes: >

# %%
sns.heatmap(sample_s.cov(), annot= True)
# Out:
# <ipython-input-62-94edc911dc4b>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sample_s.cov(), annot= True)
# <Axes: >

# %%
sns.countplot(x='Segment',data=sample_s,palette='colorblind')
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %%
print(sample_s['Region'].value_counts())
sns.countplot(x='Region',data=sample_s,palette='colorblind')
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64
# <Axes: xlabel='Region', ylabel='count'>

# %%
sns.barplot(x=sample_s['Sub-Category'], y=sample_s['Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,4))
sns.lineplot(x='Discount',y= 'Profit', data = sample_s, color = 'r', label= 'Discount')
plt.show()

# %%
sample_s.hist(bins=50,figsize=(15,8))
plt.show()

# %%
sns.pairplot(sample_s,hue='Sub-Category')
